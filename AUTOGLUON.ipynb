# %% [markdown]
# <a href="https://colab.research.google.com/github/kartikeyaGUPTA45/AUTOMATED-MACHINE-LEARNING/blob/master/AUTOGLUON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AUTOGLON

# %% [markdown]
# # INSTALLATION

# %%
# !pip install --upgrade mxnet
# !pip install autogluon
# Out:
# Collecting mxnet
#   Downloading https://files.pythonhosted.org/packages/81/f5/d79b5b40735086ff1100c680703e0f3efc830fa455e268e9e96f3c857e93/mxnet-1.6.0-py2.py3-none-any.whl (68.7MB)
#      |████████████████████████████████| 68.7MB 55kB/s
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.6/dist-packages (from mxnet) (1.18.5)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading https://files.pythonhosted.org/packages/53/39/4ab213673844e0c004bed8a0781a0721a3f6bb23eb8854ee75c236428892/graphviz-0.8.4-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: requests<3,>=2.20.0 in /usr/local/lib/python3.6/dist-packages (from mxnet) (2.23.0)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.20.0->mxnet) (1.24.3)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.20.0->mxnet) (2.9)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.20.0->mxnet) (2020.4.5.2)
# Installing collected packages: graphviz, mxnet
#   Found existing installation: graphviz 0.10.1
#     Uninstalling graphviz-0.10.1:
#       Successfully uninstalled graphviz-0.10.1
# Successfully installed graphviz-0.8.4 mxnet-1.6.0
# Collecting autogluon
#   Downloading https://files.pythonhosted.org/packages/2b/9f/b0afd77137f73090f87bb7e6f91048adb205e40ef7e6e7ff200358e3fb60/autogluon-0.0.11-py3-none-any.whl (506kB)
#      |████████████████████████████████| 512kB 3.5MB/s
# Collecting paramiko>=2.4
#   Downloading https://files.pythonhosted.org/packages/06/1e/1e08baaaf6c3d3df1459fd85f0e7d2d6aa916f33958f151ee1ecc9800971/paramiko-2.7.1-py2.py3-none-any.whl (206kB)
#      |████████████████████████████████| 215kB 11.2MB/s
# Requirement already satisfied: cython in /usr/local/lib/python3.6/dist-packages (from autogluon) (0.29.20)
# Collecting lightgbm<3.0,>=2.3.0
#   Downloading https://files.pythonhosted.org/packages/0b/9d/ddcb2f43aca194987f1a99e27edf41cf9bc39ea750c3371c2a62698c509a/lightgbm-2.3.1-py2.py3-none-manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 17.8MB/s
# Collecting Pillow<=6.2.1
#   Downloading https://files.pythonhosted.org/packages/10/5c/0e94e689de2476c4c5e644a3bd223a1c1b9e2bdb7c510191750be74fa786/Pillow-6.2.1-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 13.3MB/s
# Collecting catboost<0.24
#   Downloading https://files.pythonhosted.org/packages/b2/aa/e61819d04ef2bbee778bf4b3a748db1f3ad23512377e43ecfdc3211437a0/catboost-0.23.2-cp36-none-manylinux1_x86_64.whl (64.8MB)
#      |████████████████████████████████| 64.8MB 113kB/s
# Requirement already satisfied: dask>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from autogluon) (2.12.0)
# Collecting cryptography>=2.8
#   Downloading https://files.pythonhosted.org/packages/3c/04/686efee2dcdd25aecf357992e7d9362f443eb182ecd623f882bc9f7a6bba/cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7MB)
#      |████████████████████████████████| 2.7MB 46.1MB/s
# Collecting gluoncv<1.0,>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/fa/81/37a00609cb53da3671adb106b9bc03fb1c029ad5a8db4bc668283e65703d/gluoncv-0.7.0-py2.py3-none-any.whl (752kB)
#      |████████████████████████████████| 757kB 40.2MB/s
# Collecting scikit-optimize
#   Downloading https://files.pythonhosted.org/packages/5c/87/310b52debfbc0cb79764e5770fa3f5c18f6f0754809ea9e2fc185e1b67d3/scikit_optimize-0.7.4-py2.py3-none-any.whl (80kB)
#      |████████████████████████████████| 81kB 8.6MB/s
# Collecting tornado>=5.0.1
#   Downloading https://files.pythonhosted.org/packages/95/84/119a46d494f008969bf0c775cb2c6b3579d3c4cc1bb1b41a022aa93ee242/tornado-6.0.4.tar.gz (496kB)
#      |████████████████████████████████| 501kB 45.4MB/s
# Collecting ConfigSpace<=0.4.10
#   Downloading https://files.pythonhosted.org/packages/42/de/4e8e4f26332fc65404f52baa112defbf822b6738b60bfa6b2993f5c60933/ConfigSpace-0.4.10.tar.gz (882kB)
#      |████████████████████████████████| 890kB 41.3MB/s
# Requirement already satisfied: scikit-learn<0.23,>=0.22.0 in /usr/local/lib/python3.6/dist-packages (from autogluon) (0.22.2.post1)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from autogluon) (5.4.8)
# Requirement already satisfied: pytest in /usr/local/lib/python3.6/dist-packages (from autogluon) (3.6.4)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from autogluon) (1.18.5)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from autogluon) (1.14.2)
# Requirement already satisfied: networkx<3.0,>=2.3 in /usr/local/lib/python3.6/dist-packages (from autogluon) (2.4)
# Collecting gluonnlp==0.8.1
#   Downloading https://files.pythonhosted.org/packages/6e/2d/40c2ad37d74e5e9030064d73542b7df0f7df7ba98d47932874033cf03d79/gluonnlp-0.8.1.tar.gz (236kB)
#      |████████████████████████████████| 245kB 44.8MB/s
# Requirement already satisfied: graphviz in /usr/local/lib/python3.6/dist-packages (from autogluon) (0.8.4)
# Collecting distributed>=2.6.0
#   Downloading https://files.pythonhosted.org/packages/ed/5b/c489f407e1b48981c6c17b1e3458910882430f9fc4576b4bf9efef9140c6/distributed-2.19.0-py3-none-any.whl (643kB)
#      |████████████████████████████████| 645kB 37.5MB/s
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from autogluon) (3.2.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from autogluon) (2.23.0)
# Requirement already satisfied: scipy>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from autogluon) (1.4.1)
# Collecting pandas<1.0,>=0.24.0
#   Downloading https://files.pythonhosted.org/packages/52/3f/f6a428599e0d4497e1595030965b5ba455fd8ade6e977e3c819973c4b41d/pandas-0.25.3-cp36-cp36m-manylinux1_x86_64.whl (10.4MB)
#      |████████████████████████████████| 10.4MB 46.1MB/s
# Requirement already satisfied: tqdm>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from autogluon) (4.41.1)
# Collecting pynacl>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/9d/57/2f5e6226a674b2bcb6db531e8b383079b678df5b10cdaa610d6cf20d77ba/PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961kB)
#      |████████████████████████████████| 962kB 43.1MB/s
# Collecting bcrypt>=3.1.3
#   Downloading https://files.pythonhosted.org/packages/8b/1d/82826443777dd4a624e38a08957b975e75df859b381ae302cfd7a30783ed/bcrypt-3.1.7-cp34-abi3-manylinux1_x86_64.whl (56kB)
#      |████████████████████████████████| 61kB 7.7MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from catboost<0.24->autogluon) (1.12.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.6/dist-packages (from catboost<0.24->autogluon) (4.4.1)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.8->autogluon) (1.14.0)
# Collecting portalocker
#   Downloading https://files.pythonhosted.org/packages/53/84/7b3146ec6378d28abc73ab484f09f47dfa008ad6f03f33d90a369f880e25/portalocker-1.7.0-py2.py3-none-any.whl
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-optimize->autogluon) (0.15.1)
# Collecting pyaml>=16.9
#   Downloading https://files.pythonhosted.org/packages/15/c4/1310a054d33abc318426a956e7d6df0df76a6ddfa9c66f6310274fb75d42/pyaml-20.4.0-py2.py3-none-any.whl
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.6/dist-packages (from ConfigSpace<=0.4.10->autogluon) (2.4.7)
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from ConfigSpace<=0.4.10->autogluon) (3.6.6)
# Requirement already satisfied: atomicwrites>=1.0 in /usr/local/lib/python3.6/dist-packages (from pytest->autogluon) (1.4.0)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.6/dist-packages (from pytest->autogluon) (19.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from pytest->autogluon) (47.3.1)
# Requirement already satisfied: pluggy<0.8,>=0.5 in /usr/local/lib/python3.6/dist-packages (from pytest->autogluon) (0.7.1)
# Requirement already satisfied: py>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from pytest->autogluon) (1.8.1)
# Requirement already satisfied: more-itertools>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pytest->autogluon) (8.4.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->autogluon) (0.10.0)
# Requirement already satisfied: botocore<1.18.0,>=1.17.2 in /usr/local/lib/python3.6/dist-packages (from boto3->autogluon) (1.17.2)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->autogluon) (0.3.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx<3.0,>=2.3->autogluon) (4.4.2)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (2.0.0)
# Requirement already satisfied: cloudpickle>=1.3.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (1.3.0)
# Requirement already satisfied: toolz>=0.8.2 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (0.10.0)
# Collecting contextvars; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/83/96/55b82d9f13763be9d672622e1b8106c85acb83edd7cc2fa5bc67cd9877e9/contextvars-2.4.tar.gz
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (1.6.0)
# Requirement already satisfied: msgpack>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (1.0.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (2.2.2)
# Requirement already satisfied: click>=6.6 in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (7.1.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from distributed>=2.6.0->autogluon) (3.13)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->autogluon) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->autogluon) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->autogluon) (0.10.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->autogluon) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->autogluon) (2020.4.5.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->autogluon) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->autogluon) (2.9)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas<1.0,>=0.24.0->autogluon) (2018.9)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly->catboost<0.24->autogluon) (1.3.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.8->autogluon) (2.20)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.18.0,>=1.17.2->boto3->autogluon) (0.15.2)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.6/dist-packages (from zict>=0.1.3->distributed>=2.6.0->autogluon) (1.0.1)
# Collecting immutables>=0.9
#   Downloading https://files.pythonhosted.org/packages/99/e0/ea6fd4697120327d26773b5a84853f897a68e33d3f9376b00a8ff96e4f63/immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98kB)
#      |████████████████████████████████| 102kB 11.7MB/s
# Building wheels for collected packages: tornado, ConfigSpace, gluonnlp, contextvars
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-6.0.4-cp36-cp36m-linux_x86_64.whl size=427638 sha256=883ee0bfac792614e8545a4809ad5a88992bd8ec8417ac9d5f90486b3c7b61b7
#   Stored in directory: /root/.cache/pip/wheels/93/84/2f/409c7b2bb3afc3aa727f7ee8787975e0793f74d1165f4d0104
#   Building wheel for ConfigSpace (setup.py) ... done
#   Created wheel for ConfigSpace: filename=ConfigSpace-0.4.10-cp36-cp36m-linux_x86_64.whl size=2712277 sha256=d07c456cd4fe5f5b9bec58d6b321427cc481d17854bdd99c0540a108d6048f9f
#   Stored in directory: /root/.cache/pip/wheels/75/83/cb/28dd42bac69c8867d485138030daa83841c7f84afe68b2fdf7
#   Building wheel for gluonnlp (setup.py) ... done
#   Created wheel for gluonnlp: filename=gluonnlp-0.8.1-cp36-none-any.whl size=293521 sha256=ee49721d6263e10866f1e8d77d9617888981819870cd0df29f2ea45759022942
#   Stored in directory: /root/.cache/pip/wheels/3e/e7/3e/9cdf8ad7fce112fde2f4a52604045e5dd80f84d645bedb70c7
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-cp36-none-any.whl size=7666 sha256=49d47e444e45a8c0c78a61955a5c9adea32cfd0c0700cf0064f55d8297eacb80
#   Stored in directory: /root/.cache/pip/wheels/a5/7d/68/1ebae2668bda2228686e3c1cf16f2c2384cea6e9334ad5f6de
# Successfully built tornado ConfigSpace gluonnlp contextvars
# ERROR: google-colab 1.0.0 has requirement pandas~=1.0.0; python_version >= "3.0", but you'll have pandas 0.25.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: cryptography, pynacl, bcrypt, paramiko, lightgbm, Pillow, pandas, catboost, portalocker, gluoncv, pyaml, scikit-optimize, tornado, ConfigSpace, gluonnlp, immutables, contextvars, distributed, autogluon
#   Found existing installation: lightgbm 2.2.3
#     Uninstalling lightgbm-2.2.3:
#       Successfully uninstalled lightgbm-2.2.3
#   Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
#   Found existing installation: pandas 1.0.4
#     Uninstalling pandas-1.0.4:
#       Successfully uninstalled pandas-1.0.4
#   Found existing installation: tornado 4.5.3
#     Uninstalling tornado-4.5.3:
#       Successfully uninstalled tornado-4.5.3
#   Found existing installation: distributed 1.25.3
#     Uninstalling distributed-1.25.3:
#       Successfully uninstalled distributed-1.25.3
# Successfully installed ConfigSpace-0.4.10 Pillow-6.2.1 autogluon-0.0.11 bcrypt-3.1.7 catboost-0.23.2 contextvars-2.4 cryptography-2.9.2 distributed-2.19.0 gluoncv-0.7.0 gluonnlp-0.8.1 immutables-0.14 lightgbm-2.3.1 pandas-0.25.3 paramiko-2.7.1 portalocker-1.7.0 pyaml-20.4.0 pynacl-1.4.0 scikit-optimize-0.7.4 tornado-6.0.4

# %% [markdown]
# # IMPORTING AUTOGLUON

# %%
import autogluon as ag
from autogluon import TabularPrediction as task

# %%
train_data = task.Dataset(file_path='https://autogluon.s3.amazonaws.com/datasets/Inc/train.csv')
test_data = task.Dataset(file_path='https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv')
# Out:
# Loaded data from: https://autogluon.s3.amazonaws.com/datasets/Inc/train.csv | Columns = 15 / 15 | Rows = 39073 -> 39073
# Loaded data from: https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv | Columns = 15 / 15 | Rows = 9769 -> 9769

# %% [markdown]
# # IMPORTING DATASET

# %%
print(train_data.head())
# Out:
#    age   workclass  fnlwgt  ... hours-per-week  native-country   class
# 0   25     Private  178478  ...             40   United-States   <=50K
# 1   23   State-gov   61743  ...             35   United-States   <=50K
# 2   46     Private  376789  ...             15   United-States   <=50K
# 3   55           ?  200235  ...             50   United-States    >50K
# 4   36     Private  224541  ...             40     El-Salvador   <=50K
#
# [5 rows x 15 columns]

# %%
print(train_data.describe())
# Out:
#                 age        fnlwgt  ...  capital-loss  hours-per-week
# count  39073.000000  3.907300e+04  ...  39073.000000    39073.000000
# mean      38.616743  1.899605e+05  ...     88.002866       40.407673
# std       13.718529  1.055563e+05  ...    403.732117       12.362809
# min       17.000000  1.349200e+04  ...      0.000000        1.000000
# 25%       28.000000  1.177740e+05  ...      0.000000       40.000000
# 50%       37.000000  1.783410e+05  ...      0.000000       40.000000
# 75%       48.000000  2.383420e+05  ...      0.000000       45.000000
# max       90.000000  1.490400e+06  ...   4356.000000       99.000000
#
# [8 rows x 6 columns]

# %%
predictor = task.fit(train_data=train_data, label='class')
performance = predictor.evaluate(test_data)
# Out:
# No output_directory specified. Models will be saved in: AutogluonModels/ag-20200620_023157/
# Beginning AutoGluon training ...
# AutoGluon will save models to AutogluonModels/ag-20200620_023157/
# Train Data Rows:    39073
# Train Data Columns: 15
# Preprocessing data ...
# Here are the 2 unique label values in your data:  [' <=50K', ' >50K']
# AutoGluon infers your prediction problem is: binary  (because only two unique label-values observed).
# If this is wrong, please specify `problem_type` argument in fit() instead (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
#
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# Train Data Class Count: 2
# NumExpr defaulting to 2 threads.
# Feature Generator processed 39073 data points with 14 features
# Original Features:
# 	int features: 6
# 	object features: 8
# Generated Features:
# 	int features: 0
# All Features:
# 	int features: 6
# 	object features: 8
# 	Data preprocessing and feature engineering runtime = 0.38s ...
# AutoGluon will gauge predictive performance using evaluation metric: accuracy
# To change this, specify the eval_metric argument of fit()
# AutoGluon will early stop models using evaluation metric: accuracy
# Fitting model: RandomForestClassifierGini ...
# 	0.858	 = Validation accuracy score
# 	13.63s	 = Training runtime
# 	0.42s	 = Validation runtime
# Fitting model: RandomForestClassifierEntr ...
# 	0.8584	 = Validation accuracy score
# 	14.77s	 = Training runtime
# 	0.32s	 = Validation runtime
# Fitting model: ExtraTreesClassifierGini ...
# 	0.846	 = Validation accuracy score
# 	9.21s	 = Training runtime
# 	0.42s	 = Validation runtime
# Fitting model: ExtraTreesClassifierEntr ...
# 	0.8412	 = Validation accuracy score
# 	10.1s	 = Training runtime
# 	0.42s	 = Validation runtime
# Fitting model: KNeighborsClassifierUnif ...
# 	0.7752	 = Validation accuracy score
# 	0.25s	 = Training runtime
# 	0.14s	 = Validation runtime
# Fitting model: KNeighborsClassifierDist ...
# 	0.766	 = Validation accuracy score
# 	0.25s	 = Training runtime
# 	0.12s	 = Validation runtime
# Fitting model: LightGBMClassifier ...
# 	0.8812	 = Validation accuracy score
# 	0.96s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: CatboostClassifier ...
# 	0.8848	 = Validation accuracy score
# 	14.09s	 = Training runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetClassifier ...
# 	0.8652	 = Validation accuracy score
# 	362.09s	 = Training runtime
# 	0.31s	 = Validation runtime
# Fitting model: LightGBMClassifierCustom ...
# 	0.8828	 = Validation accuracy score
# 	2.56s	 = Training runtime
# 	0.07s	 = Validation runtime
# Fitting model: weighted_ensemble_k0_l1 ...
# 	0.8852	 = Validation accuracy score
# 	1.47s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 445.48s ...
# Predictive performance on given dataset: accuracy = 0.8756269833145665

# %%
predictor.leaderboard(test_data)
# Out:
#                          model  score_test  score_val  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer
# 0      weighted_ensemble_k0_l1    0.875627     0.8852        3.294220       1.355055   55.264186                 0.022360                0.001966           1.470709            1       True
# 1           CatboostClassifier    0.875013     0.8848        0.035541       0.019850   14.093170                 0.035541                0.019850          14.093170            0       True
# 2           LightGBMClassifier    0.874603     0.8812        0.056521       0.029832    0.957988                 0.056521                0.029832           0.957988            0       True
# 3     LightGBMClassifierCustom    0.874296     0.8828        0.242966       0.068181    2.563554                 0.242966                0.068181           2.563554            0       True
# 4   RandomForestClassifierEntr    0.858737     0.8584        0.819158       0.324576   14.769005                 0.819158                0.324576          14.769005            0       True
# 5   RandomForestClassifierGini    0.858737     0.8580        0.819526       0.424111   13.626033                 0.819526                0.424111          13.626033            0       True
# 6          NeuralNetClassifier    0.856792     0.8652        1.306009       0.314405  362.087919                 1.306009                0.314405         362.087919            0       True
# 7     ExtraTreesClassifierGini    0.845941     0.8460        1.315494       0.418282    9.209996                 1.315494                0.418282           9.209996            0       True
# 8     ExtraTreesClassifierEntr    0.845327     0.8412        1.420688       0.417095   10.098755                 1.420688                0.417095          10.098755            0       True
# 9     KNeighborsClassifierUnif    0.773365     0.7752        0.120426       0.137626    0.248527                 0.120426                0.137626           0.248527            0       True
# 10    KNeighborsClassifierDist    0.762514     0.7660        0.794769       0.116003    0.254908                 0.794769                0.116003           0.254908            0       True
#                          model  score_test  ...  stack_level  can_infer
# 0      weighted_ensemble_k0_l1    0.875627  ...            1       True
# 1           CatboostClassifier    0.875013  ...            0       True
# 2           LightGBMClassifier    0.874603  ...            0       True
# 3     LightGBMClassifierCustom    0.874296  ...            0       True
# 4   RandomForestClassifierEntr    0.858737  ...            0       True
# 5   RandomForestClassifierGini    0.858737  ...            0       True
# 6          NeuralNetClassifier    0.856792  ...            0       True
# 7     ExtraTreesClassifierGini    0.845941  ...            0       True
# 8     ExtraTreesClassifierEntr    0.845327  ...            0       True
# 9     KNeighborsClassifierUnif    0.773365  ...            0       True
# 10    KNeighborsClassifierDist    0.762514  ...            0       True
#
# [11 rows x 11 columns]

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                          model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer
# 0      weighted_ensemble_k0_l1     0.8856       0.658934   32.534718                0.001860           1.498606            1       True
# 1           CatboostClassifier     0.8848       0.020731   13.303366                0.020731          13.303366            0       True
# 2     LightGBMClassifierCustom     0.8828       0.070270    4.695547                0.070270           4.695547            0       True
# 3           LightGBMClassifier     0.8812       0.025949    1.913553                0.025949           1.913553            0       True
# 4          NeuralNetClassifier     0.8652       0.319405  353.014586                0.319405         353.014586            0       True
# 5   RandomForestClassifierEntr     0.8600       0.320371   13.183390                0.320371          13.183390            0       True
# 6   RandomForestClassifierGini     0.8564       0.318218   10.166731                0.318218          10.166731            0       True
# 7     ExtraTreesClassifierGini     0.8464       0.318497    8.265132                0.318497           8.265132            0       True
# 8     ExtraTreesClassifierEntr     0.8440       0.317847    9.467614                0.317847           9.467614            0       True
# 9     KNeighborsClassifierUnif     0.7752       0.120104    0.279602                0.120104           0.279602            0       True
# 10    KNeighborsClassifierDist     0.7660       0.117614    0.227945                0.117614           0.227945            0       True
# Number of models trained: 11
# Types of models trained:
# {'CatboostModel', 'LGBModel', 'KNNModel', 'RFModel', 'XTModel', 'WeightedEnsembleModel', 'TabularNeuralNetModel'}
# Bagging used: False
# Stack-ensembling used: False
# Hyperparameter-tuning used: False
# User-specified hyperparameters:
# {'default': {'NN': [{}], 'GBM': [{}], 'CAT': [{}], 'RF': [{'criterion': 'gini', '_ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', '_ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}], 'XT': [{'criterion': 'gini', '_ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', '_ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}], 'KNN': [{'weights': 'uniform', '_ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', '_ag_args': {'name_suffix': 'Dist'}}], 'custom': [{'num_boost_round': 10000, 'num_threads': -1, 'objective': 'binary', 'metric': 'binary_logloss,binary_error', 'verbose': -1, 'boosting_type': 'gbdt', 'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 5, 'two_round': True, 'seed_value': 0, '_ag_args': {'model_type': 'GBM', 'name_suffix': 'Custom', 'disable_in_hpo': True}}]}}
# Plot summary of models saved to file: AutogluonModels/ag-20200607_101617/SummaryOfModels.html
# *** End of fit() summary ***
# {'feature_prune': False,
#  'hyperparameter_tune': False,
#  'hyperparameters_userspecified': {'default': {'CAT': [{}],
#    'GBM': [{}],
#    'KNN': [{'_ag_args': {'name_suffix': 'Unif'}, 'weights': 'uniform'},
#     {'_ag_args': {'name_suffix': 'Dist'}, 'weights': 'distance'}],
#    'NN': [{}],
#    'RF': [{'_ag_args': {'name_suffix': 'Gini',
#       'problem_types': ['binary', 'multiclass']},
#      'criterion': 'gini'},
#     {'_ag_args': {'name_suffix': 'Entr',
#       'problem_types': ['binary', 'multiclass']},
#      'criterion': 'entropy'}],
#    'XT': [{'_ag_args': {'name_suffix': 'Gini',
#       'problem_types': ['binary', 'multiclass']},
#      'criterion': 'gini'},
#     {'_ag_args': {'name_suffix': 'Entr',
#       'problem_types': ['binary', 'multiclass']},
#      'criterion': 'entropy'}],
#    'custom': [{'_ag_args': {'disable_in_hpo': True,
#       'model_type': 'GBM',
#       'name_suffix': 'Custom'},
#      'boosting_type': 'gbdt',
#      'feature_fraction': 0.9,
#      'learning_rate': 0.03,
#      'metric': 'binary_logloss,binary_error',
#      'min_data_in_leaf': 5,
#      'num_boost_round': 10000,
#      'num_leaves': 128,
#      'num_threads': -1,
#      'objective': 'binary',
#      'seed_value': 0,
#      'two_round': True,
#      'verbose': -1}]}},
#  'leaderboard':                          model  score_val  ...  stack_level  can_infer
#  0      weighted_ensemble_k0_l1     0.8856  ...            1       True
#  1           CatboostClassifier     0.8848  ...            0       True
#  2     LightGBMClassifierCustom     0.8828  ...            0       True
#  3           LightGBMClassifier     0.8812  ...            0       True
#  4          NeuralNetClassifier     0.8652  ...            0       True
#  5   RandomForestClassifierEntr     0.8600  ...            0       True
#  6   RandomForestClassifierGini     0.8564  ...            0       True
#  7     ExtraTreesClassifierGini     0.8464  ...            0       True
#  8     ExtraTreesClassifierEntr     0.8440  ...            0       True
#  9     KNeighborsClassifierUnif     0.7752  ...            0       True
#  10    KNeighborsClassifierDist     0.7660  ...            0       True
#
#  [11 rows x 8 columns],
#  'model_best': 'weighted_ensemble_k0_l1',
#  'model_fit_times': {'CatboostClassifier': 13.303365707397461,
#   'ExtraTreesClassifierEntr': 9.467613697052002,
#   'ExtraTreesClassifierGini': 8.265132427215576,
#   'KNeighborsClassifierDist': 0.22794532775878906,
#   'KNeighborsClassifierUnif': 0.27960205078125,
#   'LightGBMClassifier': 1.913553237915039,
#   'LightGBMClassifierCustom': 4.695547342300415,
#   'NeuralNetClassifier': 353.01458644866943,
#   'RandomForestClassifierEntr': 13.183390378952026,
#   'RandomForestClassifierGini': 10.166730642318726,
#   'weighted_ensemble_k0_l1': 1.4986062049865723},
#  'model_hyperparams': {'CatboostClassifier': {'allow_writing_files': False,
#    'eval_metric': 'Accuracy',
#    'iterations': 10000,
#    'learning_rate': 0.1,
#    'random_seed': 0},
#   'ExtraTreesClassifierEntr': {'criterion': 'entropy',
#    'n_estimators': 300,
#    'n_jobs': -1},
#   'ExtraTreesClassifierGini': {'criterion': 'gini',
#    'n_estimators': 300,
#    'n_jobs': -1},
#   'KNeighborsClassifierDist': {'n_jobs': -1, 'weights': 'distance'},
#   'KNeighborsClassifierUnif': {'n_jobs': -1, 'weights': 'uniform'},
#   'LightGBMClassifier': {'boosting_type': 'gbdt',
#    'metric': 'binary_logloss,binary_error',
#    'num_boost_round': 10000,
#    'num_threads': -1,
#    'objective': 'binary',
#    'two_round': True,
#    'verbose': -1},
#   'LightGBMClassifierCustom': {'boosting_type': 'gbdt',
#    'feature_fraction': 0.9,
#    'learning_rate': 0.03,
#    'metric': 'binary_logloss,binary_error',
#    'min_data_in_leaf': 5,
#    'num_boost_round': 10000,
#    'num_leaves': 128,
#    'num_threads': -1,
#    'objective': 'binary',
#    'seed_value': 0,
#    'two_round': True,
#    'verbose': -1},
#   'NeuralNetClassifier': {'activation': 'relu',
#    'base_lr': 3e-05,
#    'batch_size': 512,
#    'clip_gradient': 100.0,
#    'dropout_prob': 0.1,
#    'embed_exponent': 0.56,
#    'embedding_size_factor': 1.0,
#    'epochs_wo_improve': 20,
#    'layers': None,
#    'learning_rate': 0.0003,
#    'loss_function': None,
#    'lr_decay': 0.1,
#    'lr_scheduler': None,
#    'max_embedding_dim': 100,
#    'max_layer_width': 2056,
#    'momentum': 0.9,
#    'network_type': 'widedeep',
#    'num_epochs': 500,
#    'numeric_embed_dim': None,
#    'optimizer': 'adam',
#    'proc.embed_min_categories': 4,
#    'proc.impute_strategy': 'median',
#    'proc.max_category_levels': 100,
#    'proc.skew_threshold': 0.99,
#    'seed_value': None,
#    'target_lr': 1.0,
#    'use_batchnorm': True,
#    'use_ngram_features': False,
#    'warmup_epochs': 10,
#    'weight_decay': 1e-06,
#    'y_range': None,
#    'y_range_extend': 0.05},
#   'RandomForestClassifierEntr': {'criterion': 'entropy',
#    'n_estimators': 300,
#    'n_jobs': -1},
#   'RandomForestClassifierGini': {'criterion': 'gini',
#    'n_estimators': 300,
#    'n_jobs': -1},
#   'weighted_ensemble_k0_l1': {'max_models': 25, 'max_models_per_type': 5}},
#  'model_paths': {'CatboostClassifier': 'AutogluonModels/ag-20200607_101617/models/CatboostClassifier/',
#   'ExtraTreesClassifierEntr': 'AutogluonModels/ag-20200607_101617/models/ExtraTreesClassifierEntr/',
#   'ExtraTreesClassifierGini': 'AutogluonModels/ag-20200607_101617/models/ExtraTreesClassifierGini/',
#   'KNeighborsClassifierDist': 'AutogluonModels/ag-20200607_101617/models/KNeighborsClassifierDist/',
#   'KNeighborsClassifierUnif': 'AutogluonModels/ag-20200607_101617/models/KNeighborsClassifierUnif/',
#   'LightGBMClassifier': 'AutogluonModels/ag-20200607_101617/models/LightGBMClassifier/',
#   'LightGBMClassifierCustom': 'AutogluonModels/ag-20200607_101617/models/LightGBMClassifierCustom/',
#   'NeuralNetClassifier': 'AutogluonModels/ag-20200607_101617/models/NeuralNetClassifier/',
#   'RandomForestClassifierEntr': 'AutogluonModels/ag-20200607_101617/models/RandomForestClassifierEntr/',
#   'RandomForestClassifierGini': 'AutogluonModels/ag-20200607_101617/models/RandomForestClassifierGini/',
#   'weighted_ensemble_k0_l1': 'AutogluonModels/ag-20200607_101617/models/weighted_ensemble_k0_l1/'},
#  'model_performance': {'CatboostClassifier': 0.8848,
#   'ExtraTreesClassifierEntr': 0.844,
#   'ExtraTreesClassifierGini': 0.8464,
#   'KNeighborsClassifierDist': 0.766,
#   'KNeighborsClassifierUnif': 0.7752,
#   'LightGBMClassifier': 0.8812,
#   'LightGBMClassifierCustom': 0.8828,
#   'NeuralNetClassifier': 0.8652,
#   'RandomForestClassifierEntr': 0.86,
#   'RandomForestClassifierGini': 0.8564,
#   'weighted_ensemble_k0_l1': 0.8856},
#  'model_pred_times': {'CatboostClassifier': 0.02073073387145996,
#   'ExtraTreesClassifierEntr': 0.31784677505493164,
#   'ExtraTreesClassifierGini': 0.3184969425201416,
#   'KNeighborsClassifierDist': 0.1176140308380127,
#   'KNeighborsClassifierUnif': 0.12010407447814941,
#   'LightGBMClassifier': 0.025948762893676758,
#   'LightGBMClassifierCustom': 0.07026958465576172,
#   'NeuralNetClassifier': 0.31940531730651855,
#   'RandomForestClassifierEntr': 0.3203706741333008,
#   'RandomForestClassifierGini': 0.3182179927825928,
#   'weighted_ensemble_k0_l1': 0.0018596649169921875},
#  'model_types': {'CatboostClassifier': 'CatboostModel',
#   'ExtraTreesClassifierEntr': 'XTModel',
#   'ExtraTreesClassifierGini': 'XTModel',
#   'KNeighborsClassifierDist': 'KNNModel',
#   'KNeighborsClassifierUnif': 'KNNModel',
#   'LightGBMClassifier': 'LGBModel',
#   'LightGBMClassifierCustom': 'LGBModel',
#   'NeuralNetClassifier': 'TabularNeuralNetModel',
#   'RandomForestClassifierEntr': 'RFModel',
#   'RandomForestClassifierGini': 'RFModel',
#   'weighted_ensemble_k0_l1': 'WeightedEnsembleModel'},
#  'num_bagging_folds': 0,
#  'num_classes': 2,
#  'stack_ensemble_levels': 0}
